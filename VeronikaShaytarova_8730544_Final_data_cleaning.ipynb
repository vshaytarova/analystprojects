# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/vero/Documents/Web_Analytics_&_BI/Assignments/Final_exam/covid_activity.csv')
data.head(5)
# Out:
# /Users/vero/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME REPORT_DATE  \
# 0                         2537         NaN                 NaN  2021-01-10
# 1                          266         NaN             Nunavut  2021-01-10
# 2                      3072349         NaN                 NaN  2021-01-10
# 3                       230578         NaN                 NaN  2021-01-10
# 4                          196         NaN                 NaN  2021-01-10
#
#   CONTINENT_NAME            DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  \
# 0         Africa  JHU CSSE Global Timeseries                       0
# 1        America  JHU CSSE Global Timeseries                       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1580624 entries, 0 to 1580623
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   PEOPLE_POSITIVE_CASES_COUNT      1580624 non-null  int64
#  1   COUNTY_NAME                      1460204 non-null  object
#  2   PROVINCE_STATE_NAME              1485180 non-null  object
#  3   REPORT_DATE                      1580624 non-null  object
#  4   CONTINENT_NAME                   1579286 non-null  object
#  5   DATA_SOURCE_NAME                 1580624 non-null  object
#  6   PEOPLE_DEATH_NEW_COUNT           1580624 non-null  int64
#  7   COUNTY_FIPS_NUMBER               1435228 non-null  float64
#  8   COUNTRY_ALPHA_3_CODE             1579286 non-null  object
#  9   COUNTRY_SHORT_NAME               1580624 non-null  object
#  10  COUNTRY_ALPHA_2_CODE             1578840 non-null  object
# ...
